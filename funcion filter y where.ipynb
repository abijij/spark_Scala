// %%
val df = spark.read.parquet("/Volumes/spark_scala/spark_scala/data/Seccion7/lectura44/datos (1).parquet")

// %%
display(df)

// %%
import  org.apache.spark.sql.functions.col

// %%
display(
  df.filter(col("video_id") === "2kyS6SvSYSE")
)

// %%
display(
  df.where(col("trending_date") =!= "17.15.11")
  )

// %%
df.printSchema()

// %%
display(
  df.filter(col("likes") > 5000)
)

// %%
display(
  df.filter(col("trending_date") =!= "17.14.11"&& col("likes") > 5000)
)

// %%
display(
  df.filter(col("trending_date") =!= "17.14.11").filter(col("likes") > 50000)
)
