// %%
val sc = spark.sparkContext

// %%
val rddVacio = sc.emptyRDD

// %%
val rddVacio1 = sc.parallelize(Seq(), 3)

// %%
rddVacio.getNumPartitions

// %%
rddVacio1.getNumPartitions

// %%
val rdd = sc.parallelize(Seq(1,2,3,4,5))

// %%
rdd.collect()

// %%
val dfTexto = spark.read.text("/Volumes/spark_scala/spark_scala/data/Seccion3/lectura12/rdd_source.txt")

// %%
dfTexto.collect()

// %%
rdd.collect()

// %%
val rddSuma = rdd.map(x => x + 1)
rddSuma.collect()

// %%
import spark.implicits._

// %%
val df = Seq((1, "jk"), (2, "ki")).toDF("ID", "Letras")
df.show()

// %%
val rddDF = df.rdd

// %%
rddDF.collect()
