// %%
 val df = spark.read.parquet("/Volumes/spark_scala/spark_scala/data/Seccion7/lestura43/datos.parquet")
 df.printSchema()

// %%
import org.apache.spark.sql.functions.col

// %%
 df.select(col("video_id")).show()

// %%
df.select("video_id", "title").show

// %%
df.select(
  col("likes"),
  col("dislikes"),
  (col("likes") - col("dislikes")).as("aceptation")
).show(false)

// %%
df.selectExpr("likes","dislikes", "(likes - dislikes) as aceptation").show(false)
